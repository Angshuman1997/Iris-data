# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt
df=pd.read_csv('C:\\Users\\Angshuman Bardhan\\Desktop\Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
df1=df.groupby(['Species'])['SepalLengthCm'].mean()
df1
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
# %matplotlib inline 
df1=df.groupby(['Species'])['SepalLengthCm'].mean()
df1.plot(x='Species',y='SepalLengthCm')

# %%
plt.plot(x=df['Species'],y=df['SepalLengthCm'])
# Out:
# []

# %%
l=[]
